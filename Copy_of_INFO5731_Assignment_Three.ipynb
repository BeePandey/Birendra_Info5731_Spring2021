# %% [markdown]
# <a href="https://colab.research.google.com/github/BeePandey/Birendra_Info5731_Spring2021/blob/main/Copy_of_INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
#Scapping data and converting to dataframe

import pandas as pd
import time
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By


driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt10579952/reviews?ref_=tt_ov_rt'
is_arraytitle = []
is_rarray = []
driver.get(link)
for item in range(4):
  driver.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  l_title = driver.find_elements(By.CLASS_NAME, "title")
  lreviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(l_title, lreviews):
      is_arraytitle.append((ele.text).replace('\n',''))
      is_rarray.append(sub_ele.text)
dataf = pd.DataFrame(list(zip(is_arraytitle, is_rarray)), columns =['Title', 'Review'])
dataf
# Out:
#                                                  Title                                             Review
# 0                          JD & Bhavani Stole the Show  Perfect characteristation for both VIJAY & VJS...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  Vijay & VJS is Only Lifting The Whole Movie. A...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  Great thing is about the movie is VIJAY vs VIJ...
# 3    Commercial & Predictable potboiler!Much Disapp...
# 4                              Awesome awesome awesome
# ..                                                 ...                                                ...
# 120  Director #Lokesh #Kanagaraj's #Master (2021) -...  A one man show with great music and message. p...
# 121                                       Vijay vs VJS  Master's biggest plus point is vijay sethupath...
# 122                  MASTER : Vijay V/s Vijay Show !!!  The film is the story of JD (Thalapathy Vijay)...
# ...

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /root/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /root/nltk_data...
# ...

# %% [markdown]
# Data Cleaning and Processing

# %%
#Converting to Lower Case

dataf['Lower Case'] = dataf['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
dataf
# Out:
#                                                  Title  ...                                         Lower Case
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation for both vijay & vjs...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay & vjs is only lifting the whole movie. a...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing is about the movie is vijay vs vij...
# 3    Commercial & Predictable potboiler!Much Disapp...  ...
# 4                              Awesome awesome awesome  ...
# ..                                                 ...  ...                                                ...
# 120  Director #Lokesh #Kanagaraj's #Master (2021) -...  ...  a one man show with great music and message. p...
# 121                                       Vijay vs VJS  ...  master's biggest plus point is vijay sethupath...
# ...

# %%
#Removal of Punctuation

dataf['Removal of Punctuation'] = dataf['Lower Case'].str.replace('[^\w\s]','')
dataf
# Out:
#                                                  Title  ...                             Removal of Punctuation
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation for both vijay  vjs ...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay  vjs is only lifting the whole movie ani...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing is about the movie is vijay vs vij...
# 3    Commercial & Predictable potboiler!Much Disapp...  ...
# 4                              Awesome awesome awesome  ...
# ..                                                 ...  ...                                                ...
# 120  Director #Lokesh #Kanagaraj's #Master (2021) -...  ...  a one man show with great music and message pe...
# 121                                       Vijay vs VJS  ...  masters biggest plus point is vijay sethupathi...
# ...

# %%
#Removal of Special Characters

import re
dataf['Removal of Special Characters'] = dataf['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
dataf
# Out:
#                                                  Title  ...                      Removal of Special Characters
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation for both vijay  vjs ...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay  vjs is only lifting the whole movie ani...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing is about the movie is vijay vs vij...
# 3    Commercial & Predictable potboiler!Much Disapp...  ...
# 4                              Awesome awesome awesome  ...
# ..                                                 ...  ...                                                ...
# 120  Director #Lokesh #Kanagaraj's #Master (2021) -...  ...  a one man show with great music and message pe...
# 121                                       Vijay vs VJS  ...  masters biggest plus point is vijay sethupathi...
# ...

# %%
#Removal of Stop words
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop=stopwords.words('english')
dataf['Stopwords Removal'] = dataf['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
print(dataf)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                  Title  ...                                  Stopwords Removal
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation vijay vjs 2nd half l...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay vjs lifting whole movie anirudh bgm take...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing movie vijay vs vijay make u go cra...
# 3    Commercial & Predictable potboiler!Much Disapp...  ...
# 4                              Awesome awesome awesome  ...
# ..                                                 ...  ...                                                ...
# 120  Director #Lokesh #Kanagaraj's #Master (2021) -...  ...  one man show great music message people loved ...
# ...

# %%
#Stemming

from nltk.stem import PorterStemmer
st = PorterStemmer()
dataf['After Stemming'] = dataf['Stopwords Removal'].apply(lambda x: " ".join([st.stem(word) for word in x]))
dataf
# Out:
#                                                  Title  ...                                     After Stemming
# 0                          JD & Bhavani Stole the Show  ...  p e r f e c t   c h a r a c t e r i s t a t i ...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  v i j a y   v j s   l i f t i n g   w h o l e ...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  g r e a t   t h i n g   m o v i e   v i j a y ...
# 3    Commercial & Predictable potboiler!Much Disapp...  ...
# 4                              Awesome awesome awesome  ...
# ..                                                 ...  ...                                                ...
# 120  Director #Lokesh #Kanagaraj's #Master (2021) -...  ...  o n e   m a n   s h o w   g r e a t   m u s i ...
# 121                                       Vijay vs VJS  ...  m a s t e r s   b i g g e s t   p l u s   p o ...
# ...

# %%
#Lemmatization

from textblob import Word
import nltk
nltk.download('wordnet')

dataf['After Lemmatization'] = dataf['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
dataf
dataf.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# 1.1 - Trigrams

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize


sentencesword = []
for sentence in dataf['After Lemmatization']:
  sentencesword.append(word_tokenize(sentence))
is_cleaning = [x for x in sentencesword if x != []]
iterations = list(itertools.chain.from_iterable(is_cleaning))


tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('p', 'e', 'r'): 77,
#           ('e', 'r', 'f'): 63,
#           ('r', 'f', 'e'): 17,
#           ('f', 'e', 'c'): 20,
#           ('e', 'c', 't'): 56,
#           ('c', 't', 'c'): 3,
#           ('t', 'c', 'h'): 60,
#           ('c', 'h', 'a'): 33,
#           ('h', 'a', 'r'): 29,
#           ('a', 'r', 'a'): 38,
#           ('r', 'a', 'c'): 27,
#           ('a', 'c', 't'): 92,
#           ('c', 't', 'e'): 32,
#           ('t', 'e', 'r'): 152,
#           ('e', 'r', 'i'): 31,
#           ('r', 'i', 's'): 18,
#           ('i', 's', 't'): 28,
#           ('s', 't', 'a'): 24,
#           ('t', 'a', 't'): 4,
#           ('a', 't', 'i'): 42,
#           ('t', 'i', 'o'): 73,
#           ('i', 'o', 'n'): 83,
#           ('o', 'n', 'v'): 6,
#           ('n', 'v', 'i'): 10,
#           ('v', 'i', 'j'): 152,
#           ('i', 'j', 'a'): 152,
#           ('j', 'a', 'y'): 151,
#           ('a', 'y', 'v'): 28,
#           ('y', 'v', 'j'): 11,
#           ('v', 'j', 's'): 28,
# ...

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here

import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = dataf["Stopwords Removal"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
#            token         0         1  ...       122       123       124
# 0           long  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1                 0.083231  0.128755  ...  0.043671  0.149787  0.013021
# 2         scored  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3     dhurairajs  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4          drugs  0.000000  0.000000  ...  0.043671  0.000000  0.000000
# ...          ...       ...       ...  ...       ...       ...       ...
# 1190       never  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1191      coolie  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1192      rating  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1193     runtime  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1194      nailed  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
# [1195 rows x 126 columns]

# %% [markdown]
# Cosine Similarity

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

query_sentence = 'The perfect portrait of a decline to insanity" & Joaquin Phoenix portrays this flawlessly in a performance of a lifetime. Choreographed impeccably by Todd Phillips & is nothing short of breathtaking. The cinematography & backdrop ideology of such an original film for such a complex character is only complimented by the superb soundtrack & acting. A hauntingly beautiful film & A Definate 10/10. Edit: Bring on part 2 plssssss!. We all want it!.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  is_vector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in is_vector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return is_vector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %%
  
similaritem = []
for sentence in dataf['Stopwords Removal']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  is_vector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(is_vector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similaritem.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(dataf['Review'],similaritem)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                Reviews Cosine Similarity
# 0    Perfect characteristation for both VIJAY & VJS...         0.0222277
# 1    Vijay & VJS is Only Lifting The Whole Movie. A...                 0
# 2    Great thing is about the movie is VIJAY vs VIJ...         0.0434783
# 3                                                                   None
# 4                                                                   None
# ..                                                 ...               ...
# 120  A one man show with great music and message. p...                 0
# 121  Master's biggest plus point is vijay sethupath...         0.0494535
# 122  The film is the story of JD (Thalapathy Vijay)...         0.0491473
# 123  LEGEND VS LEGEND.... definitely movie is Epic....                 0
# 124  After proving his mettle as a filmmaker in his...         0.0348129
#
# [125 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %% [markdown]
# # The GitHub link of your final csv file
# https://raw.githubusercontent.com/BeePandey/Birendra_Info5731_Spring2021/main/TrainingandEvaluationWest3.csv
