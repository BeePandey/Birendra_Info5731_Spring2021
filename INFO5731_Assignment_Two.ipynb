# %% [markdown]
# <a href="https://colab.research.google.com/github/BeePandey/Birendra_Info5731_Spring2021/blob/main/INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#CovidVaccine"](https://twitter.com/hashtag/CovidVaccine) from Twitter.

# %%
sdf

# %%
# Write your code here
# !pip install tweepy
import tweepy
import csv
import pandas as pd
import json


Tweeter_Feed = dict()
Tweeter_Feed['CONSUMER_KEY'] = 'u7L1lnR7HN85dn1qnTFO1cegb'
Tweeter_Feed['CONSUMER_SECRET'] = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
Tweeter_Feed['ACCESS_KEY'] = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
Tweeter_Feed['ACCESS_SECRET'] = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'
ListofTweets=[]
NoofTweets=[]
with open('twitter_credentials.json', 'w') as info:
  json.dump(tweet_cred, info, indent=4, sort_keys=True)
with open('twitter_credentials.json') as cred_data:
  info = json.load(cred_data)
  consumer_key = info['CONSUMER_KEY']
  consumer_secret = info['CONSUMER_SECRET']
  access_key = info['ACCESS_KEY']
  access_secret = info['ACCESS_SECRET']
  auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
  api1 = tweepy.API(auth)
  Tweets_Needed = int(input('No of Tweets '))
  hashtag = input('No of Hash Tag To Scrape- ')

  for tweet in tweepy.Cursor(api1.search, q='#' + hashtag, rpp=100).items(Tweets_Needed):
    ListofTweets.append(tweet)
    NoofTweets.append(tweet.text)
Is_CovidTweets=pd.DataFrame({'tweets':NoofTweets,'Is_ListTweets':ListofTweets})
Is_CovidTweets.to_csv('corona_vaccine.csv')
print(Is_CovidTweets[:10])
print('Extracted ' + str(Tweets_Needed) + ' tweets with hashtag #' + hashtag)
# Out:
# ...
# No of Tweets 15
# No of Hash Tag To Scrape- 1
#                                               tweets                                      Is_ListTweets
# 0  RT @Kookie6644: อิจฉาแทแทที่สุด \n\n🐰งั้นผมจะอ...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 1  RT @cocoa55a3: 🎁PayPay🎁\n\n🍀777円🍀\n\nーーーーーーーーー...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 2         RT @EliteSonicFan: https://t.co/ktpLsCP5sc  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 3  RT @faporizer: imagine how long it takes for s...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 4  RT @HN331945: しんだ親友に告白された話\n（1/4） https://t.co...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 5  プラチナ@1\nプラ2、プラ1\nプラ2↑の方お願いします～\n前スプ💎↑\n雰囲気良くやり...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 6  滝沢歌舞伎初回限定盤ポストカード/通常盤デタカ交換\n\n求|| 宮舘\n譲|| 画像参照\...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# ...

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
#Remove noise and special characters and punctuations

Is_CovidTweets['tweets']=Is_CovidTweets['tweets'].str.replace('[!-;:,<>./?@#$%^&*_~{}]','')
print(Is_CovidTweets)
# Out:
#                                                tweets                                      Is_ListTweets
# 0   RT Kookie อิจฉาแทแทที่สุด \n\n🐰งั้นผมจะอาบน้ำ ...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 1   RT cocoaa 🎁PayPay🎁\n\n🍀円🍀\n\nーーーーーーーーー\n★RTのみ\...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 2                  RT EliteSonicFan httpstcoktpLsCPsc  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 3   RT faporizer imagine how long it takes for sme...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 4            RT HN しんだ親友に告白された話\n（） httpstcocLEFgCnZi  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 5   プラチナ\nプラ、プラ\nプラ↑の方お願いします～\n前スプ💎↑\n雰囲気良くやりましょ～\...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 6   滝沢歌舞伎初回限定盤ポストカード通常盤デタカ交換\n\n求|| 宮舘\n譲|| 画像参照\n...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 7              簡単に遊びたいなぁ？\n寂しい時間嫌い\n出戻って１からスタート。ＤＭにて。  Status(_api=<tweepy.api.API object at 0x7f5efa...
# ...

# %%
#Remove Numbers
Is_CovidTweets['tweets']=Is_CovidTweets['tweets'].str.replace('\d','')
print(Is_CovidTweets)
# Out:
#                                                tweets                                      Is_ListTweets
# 0   rt brevkass ohboywhatashot denmark thousand in...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# 1   rt talkimhangar wir werden da problem erst lös...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# 2   rt drpuerner 👉verweilverbot stadt u ufergebiet...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# 3   rt bdzakelijk je maanden bijzond uitstel van b...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# 4   rt minvw positief getest op corona dan belt ee...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# 5   rt drpuerner 👉verweilverbot stadt u ufergebiet...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# 6   rt trdsrlz wa ich nicht versteh auf facebook s...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# 7   rt fleurhassann wa happi talk even inewsen jer...  Status(_api=<tweepy.api.API object at 0x7f5f53...
# ...

# %%
 #Remove stopwords by using the stopwords list.
 from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop=stopwords.words('english')
Is_CovidTweets['tweets']=Is_CovidTweets['tweets'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
print(Is_CovidTweets)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                tweets                                      Is_ListTweets
# 0   RT Kookie อิจฉาแทแทที่สุด 🐰งั้นผมจะอาบน้ำ พี่ก...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 1   RT cocoaa 🎁PayPay🎁 🍀円🍀 ーーーーーーーーー ★RTのみ ーーーーーーー...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 2                  RT EliteSonicFan httpstcoktpLsCPsc  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 3   RT faporizer imagine long takes smells reach b...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 4             RT HN しんだ親友に告白された話 （） httpstcocLEFgCnZi  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 5   プラチナ プラ、プラ プラ↑の方お願いします～ 前スプ💎↑ 雰囲気良くやりましょ～ オクタン...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 6   滝沢歌舞伎初回限定盤ポストカード通常盤デタカ交換 求|| 宮舘 譲|| 画像参照 目黒・渡辺...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# ...

# %%
#Lowercase All Text 

Is_CovidTweets['tweets']=Is_CovidTweets['tweets'].apply(lambda x: " ".join(x.lower() for x in x.split()))
print(Is_CovidTweets)
# Out:
#                                                tweets                                      Is_ListTweets
# 0   rt kookie อิจฉาแทแทที่สุด 🐰งั้นผมจะอาบน้ำ พี่ก...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 1   rt cocoaa 🎁paypay🎁 🍀円🍀 ーーーーーーーーー ★rtのみ ーーーーーーー...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 2                  rt elitesonicfan httpstcoktplscpsc  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 3   rt faporizer imagine long takes smells reach b...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 4             rt hn しんだ親友に告白された話 （） httpstcoclefgcnzi  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 5   プラチナ プラ、プラ プラ↑の方お願いします～ 前スプ💎↑ 雰囲気良くやりましょ～ オクタン...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 6   滝沢歌舞伎初回限定盤ポストカード通常盤デタカ交換 求|| 宮舘 譲|| 画像参照 目黒・渡辺...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 7                簡単に遊びたいなぁ？ 寂しい時間嫌い 出戻って１からスタート。ｄｍにて。  Status(_api=<tweepy.api.API object at 0x7f5efa...
# ...

# %%
#Stemming 
from nltk.stem import PorterStemmer
st=PorterStemmer()
Is_CovidTweets['tweets']=Is_CovidTweets['tweets'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
print(Is_CovidTweets)
# Out:
#                                                tweets                                      Is_ListTweets
# 0   rt kooki อิจฉาแทแทที่สุด 🐰งั้นผมจะอาบน้ำ พี่ก็...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 1   rt cocoaa 🎁paypay🎁 🍀円🍀 ーーーーーーーーー ★rtのみ ーーーーーーー...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 2                  rt elitesonicfan httpstcoktplscpsc  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 3   rt fapor imagin long take smell reach brain ht...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 4             rt hn しんだ親友に告白された話 （） httpstcoclefgcnzi  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 5   プラチナ プラ、プラ プラ↑の方お願いします～ 前スプ💎↑ 雰囲気良くやりましょ～ オクタン...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 6   滝沢歌舞伎初回限定盤ポストカード通常盤デタカ交換 求|| 宮舘 譲|| 画像参照 目黒・渡辺...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 7                簡単に遊びたいなぁ？ 寂しい時間嫌い 出戻って１からスタート。ｄｍにて。  Status(_api=<tweepy.api.API object at 0x7f5efa...
# ...

# %%
#Lemmatization 
import nltk
from textblob import Word
nltk.download('wordnet')
Is_CovidTweets['tweets']=Is_CovidTweets['tweets'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
print(Is_CovidTweets)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                tweets                                      Is_ListTweets
# 0   rt kooki อิจฉาแทแทที่สุด 🐰งั้นผมจะอาบน้ำ พี่ก็...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 1   rt cocoaa 🎁paypay🎁 🍀円🍀 ーーーーーーーーー ★rtのみ ーーーーーーー...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 2                  rt elitesonicfan httpstcoktplscpsc  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 3   rt fapor imagin long take smell reach brain ht...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 4             rt hn しんだ親友に告白された話 （） httpstcoclefgcnzi  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 5   プラチナ プラ、プラ プラ↑の方お願いします～ 前スプ💎↑ 雰囲気良くやりましょ～ オクタン...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# 6   滝沢歌舞伎初回限定盤ポストカード通常盤デタカ交換 求|| 宮舘 譲|| 画像参照 目黒・渡辺...  Status(_api=<tweepy.api.API object at 0x7f5efa...
# ...

# %%
#NewFiles 

Is_CovidTweets.to_csv('NewCsvFiles.csv')

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# !pip install benepar

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
Is_Speech=[]
Is_ab=[]
ab=0
for i in Is_CovidTweets['tweets']:
  token=nltk.word_tokenize(i)
  Is_Speech.append(nltk.pos_tag(token,tagset='universal'))
  Is_ab.append(nltk.FreqDist(tag for (word, tag) in Is_Speech[0]))
  print(Is_Speech[ab])
  print(Is_ab[ab])
  ab+=1
print(Is_ab)
import spacy
from spacy import displacy
l=spacy.load('en_core_web_sm')
for j in Is_CovidTweets['tweets']:
  displacy.render(l(j),jupyter=True)
# %tensorflow_version 1.x
import benepar
import nltk
benepar.download('benepar_en3')
from benepar.spacy_plugin import BeneparComponent
n= spacy.load('en')
n.add_pipe(BeneparComponent('benepar_en3'))
for i in Is_CovidTweets['tweets']:
  k= n(i)
  IS_P = list(k.sents)[0]
  print(IS_P._.parse_string)
import spacy
from spacy import displacy
l1=[]
q = spacy.load('en_core_web_sm')
for i in Is_CovidTweets['tweets']:
  for j in q(i).ents:
    l1.append((j.label_,j.text))
    print(j.label_,j.text)
nltk.FreqDist(label for (label, text) in l1)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [('rt', 'NOUN'), ('kooki', 'NOUN'), ('อิจฉาแทแทที่สุด', 'NOUN'), ('🐰งั้นผมจะอาบน้ำ', 'NOUN'), ('พี่ก็ไลฟไปนะครับ', 'NOUN'), ('kookv', 'VERB'), ('httpstcomkcygmsfm', 'NOUN')]
# <FreqDist with 2 samples and 7 outcomes>
# [('rt', 'NOUN'), ('cocoaa', 'NOUN'), ('🎁paypay🎁', 'NOUN'), ('🍀円🍀', 'NOUN'), ('ーーーーーーーーー', 'NOUN'), ('★rtのみ', 'NOUN'), ('ーーーーーーーーー', 'NOUN'), ('♡♡♡♡♡', 'NOUN'), ('締切', 'NOUN')]
# <FreqDist with 2 samples and 7 outcomes>
# [('rt', 'NOUN'), ('elitesonicfan', 'NOUN'), ('httpstcoktplscpsc', 'NOUN')]
# ...

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %% [markdown]
# Constituency parsing tree this displays the syntactic structure of the sentence using the grammar which is a context-free grammer.Constituency parsing/Syntatcical parsing
# is breaking a text into sub-texts/sub-phrases and this sub-text can be referred to as constituents.This type of parsing defines the syntactical structure of a selected sentence.
# It consists of Sentence constituents, parts of speech tags and sentence words.
#
# Dependency parsing defines the grammatical structure of a selected sentence by considering each word as a node. This type of parsing relies on dependency grammar.
# Here, each word is connected according to their relationships.
# '''
